# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\ssshu\OneDrive\Desktop\water_quality\data\water_dataX1.csv")

# %%
data
# Out:
#      STATION CODE                                          LOCATIONS  \
# 0            1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1            1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2            1475                                ZUARI AT PANCHAWADI
# 3            3181                        RIVER ZUARI AT BORIM BRIDGE
# 4            3182                       RIVER ZUARI AT MARCAIM JETTY
# 5            1400             MANDOVI AT NEGHBOURHOOD OF PANAJI, GOA
# 6            1476                     MANDOVI AT TONCA, MARCELA, GOA
# 7            3185                      RIVER MANDOVI AT AMONA BRIDGE
# 8            3186                        RIVER MANDOVI AT IFFI JETTY
# 9            3187                   RIVER MANDOVI NEAR HOTEL MARRIOT
# 10           1543              RIVER KALNA AT CHANDELNAN PERNEM, GOA
# 11           1548                    RIVER ASSONORA AT ASSONORA, GOA
# 12           2276            RIVER BICHOLIM VARAZAN NAGAR , BICHOLIM
# ...

# %%
#analysing the dataset
data.describe()
# Out:
#               year
# count  1991.000000
# mean   2010.038172
# std       3.057333
# min    2003.000000
# 25%    2008.000000
# 50%    2011.000000
# 75%    2013.000000
# max    2014.000000

# %%
#analysis of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 12 columns):
# STATION CODE                        1991 non-null object
# LOCATIONS                           1991 non-null object
# STATE                               1991 non-null object
# Temp                                1987 non-null object
# D.O. (mg/l)                         1991 non-null object
# PH                                  1991 non-null object
# CONDUCTIVITY (�mhos/cm)             1991 non-null object
# B.O.D. (mg/l)                       1988 non-null object
# NITRATENAN N+ NITRITENANN (mg/l)    1986 non-null object
# FECAL COLIFORM (MPN/100ml)          1978 non-null object
# TOTAL COLIFORM (MPN/100ml)Mean      1980 non-null object
# year                                1991 non-null int64
# dtypes: int64(1), object(11)
# memory usage: 186.7+ KB

# %%
data.shape
# Out:
# (1991, 12)

# %%
#checking for null values
data.isnull().any()
# Out:
# STATION CODE                        False
# LOCATIONS                           False
# STATE                               False
# Temp                                 True
# D.O. (mg/l)                         False
# PH                                  False
# CONDUCTIVITY (�mhos/cm)             False
# B.O.D. (mg/l)                        True
# NITRATENAN N+ NITRITENANN (mg/l)     True
# FECAL COLIFORM (MPN/100ml)           True
# TOTAL COLIFORM (MPN/100ml)Mean       True
# year                                False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# STATION CODE                         0
# LOCATIONS                            0
# STATE                                0
# Temp                                 4
# D.O. (mg/l)                          0
# PH                                   0
# CONDUCTIVITY (�mhos/cm)              0
# B.O.D. (mg/l)                        3
# NITRATENAN N+ NITRITENANN (mg/l)     5
# FECAL COLIFORM (MPN/100ml)          13
# TOTAL COLIFORM (MPN/100ml)Mean      11
# year                                 0
# dtype: int64

# %%
data.isnull().any()
# Out:
# STATION CODE                        False
# LOCATIONS                           False
# STATE                               False
# Temp                                 True
# D.O. (mg/l)                         False
# PH                                  False
# CONDUCTIVITY (�mhos/cm)             False
# B.O.D. (mg/l)                        True
# NITRATENAN N+ NITRITENANN (mg/l)     True
# FECAL COLIFORM (MPN/100ml)           True
# TOTAL COLIFORM (MPN/100ml)Mean       True
# year                                False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# STATION CODE                         0
# LOCATIONS                            0
# STATE                                0
# Temp                                 4
# D.O. (mg/l)                          0
# PH                                   0
# CONDUCTIVITY (�mhos/cm)              0
# B.O.D. (mg/l)                        3
# NITRATENAN N+ NITRITENANN (mg/l)     5
# FECAL COLIFORM (MPN/100ml)          13
# TOTAL COLIFORM (MPN/100ml)Mean      11
# year                                 0
# dtype: int64

# %%
data.dtypes
# Out:
# STATION CODE                        object
# LOCATIONS                           object
# STATE                               object
# Temp                                object
# D.O. (mg/l)                         object
# PH                                  object
# CONDUCTIVITY (�mhos/cm)             object
# B.O.D. (mg/l)                       object
# NITRATENAN N+ NITRITENANN (mg/l)    object
# FECAL COLIFORM (MPN/100ml)          object
# TOTAL COLIFORM (MPN/100ml)Mean      object
# year                                 int64
# dtype: object

# %%
#converting objects to their respective data types(numerics)
data['Temp'] = pd.to_numeric(data['Temp'],errors="coerce")
data['D.O. (mg/l)'] = pd.to_numeric(data['D.O. (mg/l)'],errors="coerce")
data['PH'] = pd.to_numeric(data['PH'],errors="coerce")
data['B.O.D. (mg/l)'] = pd.to_numeric(data['B.O.D. (mg/l)'],errors="coerce")
data['CONDUCTIVITY (�mhos/cm)'] = pd.to_numeric(data['CONDUCTIVITY (�mhos/cm)'],errors="coerce")
data['NITRATENAN N+ NITRITENANN (mg/l)'] = pd.to_numeric(data['NITRATENAN N+ NITRITENANN (mg/l)'],errors="coerce")
data['TOTAL COLIFORM (MPN/100ml)Mean'] = pd.to_numeric(data['TOTAL COLIFORM (MPN/100ml)Mean'],errors="coerce")
data.dtypes
# Out:
# STATION CODE                         object
# LOCATIONS                            object
# STATE                                object
# Temp                                float64
# D.O. (mg/l)                         float64
# PH                                  float64
# CONDUCTIVITY (�mhos/cm)             float64
# B.O.D. (mg/l)                       float64
# NITRATENAN N+ NITRITENANN (mg/l)    float64
# FECAL COLIFORM (MPN/100ml)           object
# TOTAL COLIFORM (MPN/100ml)Mean      float64
# year                                  int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# STATION CODE                          0
# LOCATIONS                             0
# STATE                                 0
# Temp                                 92
# D.O. (mg/l)                          31
# PH                                    8
# CONDUCTIVITY (�mhos/cm)              25
# B.O.D. (mg/l)                        43
# NITRATENAN N+ NITRITENANN (mg/l)    225
# FECAL COLIFORM (MPN/100ml)           13
# TOTAL COLIFORM (MPN/100ml)Mean      132
# year                                  0
# dtype: int64

# %%
#filling up the null values after conversion from objects to numerics
data['Temp'].fillna(data['Temp'].median(), inplace=True)
data['PH'].fillna(data['PH'].median(), inplace=True)
data['D.O. (mg/l)'].fillna(data['D.O. (mg/l)'].median(), inplace=True)
data['CONDUCTIVITY (�mhos/cm)'].fillna(data['CONDUCTIVITY (�mhos/cm)'].median(), inplace=True)
data['B.O.D. (mg/l)'].fillna(data['B.O.D. (mg/l)'].median(), inplace =True)
data['NITRATENAN N+ NITRITENANN (mg/l)'].fillna(data['NITRATENAN N+ NITRITENANN (mg/l)'].median(), inplace=True)
data['FECAL COLIFORM (MPN/100ml)'].fillna(data['FECAL COLIFORM (MPN/100ml)'].median(), inplace =True)
data['TOTAL COLIFORM (MPN/100ml)Mean'].fillna(data['TOTAL COLIFORM (MPN/100ml)Mean'].median(), inplace=True)

# %%
#checking for null values
data.isnull().sum()
# Out:
# STATION CODE                        0
# LOCATIONS                           0
# STATE                               0
# Temp                                0
# D.O. (mg/l)                         0
# PH                                  0
# CONDUCTIVITY (�mhos/cm)             0
# B.O.D. (mg/l)                       0
# NITRATENAN N+ NITRITENANN (mg/l)    0
# FECAL COLIFORM (MPN/100ml)          0
# TOTAL COLIFORM (MPN/100ml)Mean      0
# year                                0
# dtype: int64

# %%
#deleting fecal coliform column
data.drop(["FECAL COLIFORM (MPN/100ml)"], axis=1, inplace=True)

# %%
#renaming the columns for easy access
data = data.rename(columns={'D.O. (mg/l)':'do'})
data = data.rename(columns={'CONDUCTIVITY (�mhos/cm)':'co'})
data = data.rename(columns={'B.O.D. (mg/l)':'bod'})
data = data.rename(columns={'NITRATENAN N+ NITRITENANN (mg/l)':'na'})
data = data.rename(columns={'TOTAL COLIFORM (MPN/100ml)Mean':'tc'})
data = data.rename(columns={'STATION CODE':'station'})
data = data.rename(columns={'LOCATIONS':'location'})
data = data.rename(columns={'STATE':'state'})
data = data.rename(columns={'PH':'ph'})

# %%
#calc of ph
data['npH'] = data.ph.apply(lambda x: (100 if(8.5>=x>=7)
                                      else(80 if (8.6>=x>=8.5) or (6.9>=x>=6.8)
                                          else(60 if (8.8>=x>=8.6) or (6.8>=x>=6.7)
                                              else(40 if (9>=x>=8.8) or (6.7>=x>=6.5)
                                                  else 0)))))

# %%
#calc of oxygen dissolved
data['ndo'] = data.do.apply(lambda x: (100 if (x>=6)
                                      else(80 if (6>=x>=5.1)
                                          else(60 if (5>=x>=4.1)
                                              else(40 if(4>=x>=3)
                                                  else 0)))))

# %%
#calc of total caliform
data['nco'] = data.tc.apply(lambda x: (100 if (5>=x>=0)
                                      else(80 if (50>=x>=5)
                                          else(60 if (500>=x>=50)
                                              else(40 if(10000>=x>=500)
                                                  else 0)))))

# %%
#calc of bdo
data['nbdo'] = data.bod.apply(lambda x: (100 if (3>=x>=0)
                                      else(80 if (6>=x>=3)
                                          else(60 if (80>=x>=6)
                                              else(40 if(125>=x>=80)
                                                  else 0)))))

# %%
data['nec'] = data.co.apply(lambda x: (100 if (75>=x>=0)
                                      else(80 if (150>=x>=75)
                                          else(60 if (225>=x>=150)
                                              else(40 if(300>=x>=225)
                                                  else 0)))))

# %%
data['nna'] = data.na.apply(lambda x: (100 if (20>=x>=0)
                                      else(80 if (50>=x>=20)
                                          else(60 if (100>=x>=50)
                                              else(40 if(200>=x>=100)
                                                  else 0)))))

# %%
data['wph'] = data.npH * 0.165
data['wdo'] = data.ndo * 0.281
data['wbdo'] = data.nbdo * 0.234
data['wec'] = data.nec * 0.009
data['wna'] = data.nna * 0.028
data['wco'] = data.nco * 0.281
data['wqi'] = data.wph+data.wdo+data.wbdo+data.wec+data.wna+data.wco

# %%
average = data.groupby('year')['wqi'].mean()
average.head()
# Out:
# year
# 2003    66.922727
# 2004    61.290000
# 2005    75.593950
# 2006    75.262286
# 2007    75.948000
# Name: wqi, dtype: float64

# %%
#data visualisation

import seaborn as sns
sns.lmplot(x = 'year', y = 'wqi', data=data)

# %%
x = data.iloc[:,17:23].values
y = data.iloc[:, 23: ].values

# %%
x.shape
# Out:
# (1991, 6)

# %%
y.shape
# Out:
# (1991, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=10)

# %%
x_test.shape
# Out:
# (399, 6)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)
print(x_train.shape)
print(x_test.shape)
# Out:
# (1592, 6)
# (399, 6)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,mean_squared_error,mean_absolute_error
import pickle

# %%
from sklearn.ensemble import RandomForestRegressor 
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0) 
regressor.fit(x_train, y_train)
# Out:
# C:\Users\ssshu\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100,
#                       n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                       warm_start=False)

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([82.04  , 56.9844, 62.49  , 33.34  , 60.8092, 55.82  , 82.98  ,
#        64.2878, 55.82  , 79.64  , 44.832 , 81.96  , 89.14  , 70.7578,
#        73.1704, 82.94  , 93.28  , 93.82  , 83.52  , 72.06  , 88.38  ,
#        79.64  , 66.44  , 82.94  , 87.66  , 82.76  , 85.26  , 94.    ,
#        85.08  , 83.7   , 88.2   , 93.82  , 93.82  , 76.1618, 55.131 ,
#        50.7858, 93.64  , 77.8982, 83.52  , 66.12  , 87.66  , 88.2   ,
#        79.64  , 77.7672, 72.06  , 82.04  , 78.66  , 82.76  , 46.009 ,
#        83.7   , 88.02  , 78.48  , 81.5946, 82.94  , 78.74  , 70.8   ,
#        82.04  , 87.66  , 72.86  , 77.14  , 66.44  , 72.8246, 72.1   ,
#        77.7434, 94.18  , 88.38  , 72.06  , 89.32  , 85.26  , 84.36  ,
#        82.76  , 93.28  , 82.58  , 79.46  , 72.86  , 77.3164, 50.2   ,
#        67.06  , 72.06  , 73.04  , 82.94  , 89.32  , 83.7   , 57.6128,
#        77.14  , 78.3   , 60.8092, 72.06  , 84.195 , 83.7   , 85.26  ,
# ...

# %%
from sklearn import metrics
print("MAE: ",metrics.mean_absolute_error(y_test,y_pred))
print("MSE: ",metrics.mean_squared_error(y_test,y_pred))
print("RMSE: ",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# MAE:  0.24263809523817623
# MSE:  1.0608892015037676
# RMSE:  1.0299947579981985

# %%
metrics.r2_score(y_test, y_pred)
# Out:
# 0.9926955668219684

# %%
pickle.dump(regressor,open("water_pickle.pkl","wb"))

# %%
pd.set_option('display.max_columns', None)
print(data.columns.tolist())
# Out:
# ['station', 'location', 'state', 'Temp', 'do', 'ph', 'co', 'bod', 'na', 'tc', 'year', 'npH', 'ndo', 'nco', 'nbdo', 'nec', 'nna', 'wph', 'wdo', 'wbdo', 'wec', 'wna', 'wco', 'wqi']

# %%
s=[[125,127,126,129,123,125]]
y_pred1 = regressor.predict(s)
y_pred1
# Out:
# array([99.7262])
